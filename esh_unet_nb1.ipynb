# %% [markdown]
# # Esh: Non-Monotonic Activation Function

# %% [markdown]
# ## Install Packages

# %%
# !pip install -q wandb
# !pip install -q kaggle

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-4996ee3d8d09> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/gdrive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# Change Current Working Directory
import os
os.chdir("/content/")

# %%
# !git clone https://github.com/Suresh-Rajendran/unet_poc.git

# %% [markdown]
# # Hyperparameter Sweeps

# %%
# Login to WandB
# !wandb login a96eb1d17152292d104d045304f8da02ab8fe0e1
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
import wandb
wandb.init(project="Esh_UNET_v2", entity="pes_mtech_jun21_g3")
# Out:
# ...
# Problem at: <ipython-input-12-56998fed45fe> 2 <module>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/wandb/sdk/wandb_init.py", line 1108, in init
#     run = wi.init()
#   File "/usr/local/lib/python3.8/dist-packages/wandb/sdk/wandb_init.py", line 742, in init
#     raise error
# wandb.errors.CommError: Error communicating with wandb process, exiting...
# For more info see: https://docs.wandb.ai/library/init#init-start-error
# wandb: ERROR Abnormal program exit
# ---------------------------------------------------------------------------
# CommError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/wandb/sdk/wandb_init.py in init(job_type, dir, config, project, entity, reinit, tags, group, name, notes, magic, config_exclude_keys, config_include_keys, anonymous, mode, allow_val_change, resume, force, tensorboard, sync_tensorboard, monitor_gym, save_code, id, settings)
# ...

# %%
# Imports the parameter configuration for the sweep run. To add more hyperparameters in the suite, simply edit the sweep.yaml file.
# !wandb sweep /content/esh_train_sweep.yaml    # Outputs the Sweep ID
# Out:
# wandb: Creating sweep from: /content/esh_train_sweep.yaml
# wandb: Created sweep with ID: il8r0aay
# wandb: View sweep at: https://wandb.ai/pes_mtech_jun21_g3/uncategorized/sweeps/il8r0aay
# wandb: Run sweep agent with: wandb agent pes_mtech_jun21_g3/uncategorized/il8r0aay

# %%
# !wandb agent pes_mtech_jun21_g3/uncategorized/rm2ejgba
# Out:
# wandb: Starting wandb agent 🕵️
# 2023-01-24 08:56:07,546 - wandb.wandb_agent - INFO - Running runs: []
# 2023-01-24 08:56:07,776 - wandb.wandb_agent - INFO - Agent received command: run
# 2023-01-24 08:56:07,777 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	act: relu
# 	batch_size: 32
# 	optimizer: adam
# 	version: vgg16
# 2023-01-24 08:56:07,778 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_cifar.py --act=relu --batch_size=32 --optimizer=adam --version=vgg16
# wandb: Currently logged in as: rsuresh002 (pes_mtech_jun21_g3). Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: Tracking run with wandb version 0.13.9
# wandb: Run data is saved locally in /content/wandb/run-20230124_085610-nmr1vagr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run electric-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/pes_mtech_jun21_g3/uncategorized
# ...
